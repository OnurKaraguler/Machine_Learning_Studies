# %% [markdown]
# ## Index
#
# <a href='#1'>1 Import packages</a><br>
# <a href='#2'>2 SQL Database</a><br>
# <blockquote>
# <a href='#21'>2.1 Establish a connection to SQL Database</a><br>
# <a href='#22'>2.2 Query the database table into a dataframe</a><br>
# </blockquote>
# <a href='#3'>3 Data Preprocessing</a><br>
# <blockquote>
# <a href='#31'>3.1 Investigate all the elements within each Feature </a><br>
# <a href='#32'>3.2 Missing Values </a><br>
# <a href='#33'>3.3 Drop Features Using Pearson Correlation</a><br>
# <a href='#34'>3.4 Drop Outliers</a><br>
# </blockquote>
# <a href='#4'>4. Regressions and Results</a><br>
# <blockquote>
# <a href='#41'>4.1 Separate the dataset into train and test</a><br>
# <a href='#42'>4.2 Running Machine Learning Models</a><br>
# <a href='#43'>4.3 Accuracy improvement of the selected model</a><br>
# </blockquote>
# <a href='#5'>5. Making Predictions</a><br>

# %% [markdown]
# <a id='01'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         OBJECTIVE: Prediction of annual salaries ($) of professional software developers who know Python
#    </h3>
# </div>

# %% [markdown]
# <a id='1'></a>
# <div class="alert alert-block alert-danger">
# <h2>1 Import packages</h2>
# </div>

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np 
import pandas as pd
# display all of the columns
pd.set_option('display.max_columns', None)
import math

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error, mean_absolute_error

# %% [markdown]
# <a id='2'></a>
# <div class="alert alert-block alert-danger">
# <h2>2 SQL Database</h2>
# </div>

# %% [markdown]
# <a id='21'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         2.1 Establish a connection to SQL Database
#    </h3>
# </div>

# %%
# create an engine to connect to the mysql database
from sqlalchemy import create_engine
mysql_user_pass = pd.read_csv('mysql_user_pass.csv', index_col=0)
username = mysql_user_pass['mysql_user'][0]
password = mysql_user_pass['mysql_pass'][0]

engine = create_engine(f'mysql+pymysql://{username}:{password}@localhost:3306/developer_survey_2020')

# %% [markdown]
# <a id='22'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         2.2 Query the database table into a dataframe
#    </h3>
# </div>

# %%
sql = '''
SELECT mt.Respondent, mb.MainBranch, mt.Age, cf.CompFreq, mt.ConvertedComp, c.Country, 
el.EdLevel, e.Employment, js.JobSat,
mt.LanguageWorkedWith, os.OpSys, ogs.OrgSize, um.UndergradMajor, mt.YearsCode, mt.YearsCodePro
FROM developer_survey_2020.main_table  mt

JOIN MainBranch mb
	ON mb.index=mt.MainBranch
JOIN CompFreq cf
	ON cf.index=mt.CompFreq
JOIN Country c
	ON c.index=mt.Country
JOIN CurrencySymbol cs
	ON cs.index=mt.CurrencySymbol
JOIN CurrencyDesc cd
	ON cd.index=mt.CurrencyDesc
JOIN EdLevel el
	ON el.index=mt.EdLevel
JOIN Employment e
	ON e.index=mt.Employment
JOIN JobSat js
	ON js.index=mt.JobSat
JOIN OpSys os
	ON os.index=mt.OpSys
JOIN OrgSize ogs
	ON ogs.index=mt.OrgSize
JOIN UndergradMajor um
	ON um.index=mt.UndergradMajor
    
WHERE mb.MainBranch='I am a developer by profession' AND
cf.CompFreq='Yearly' AND 
e.Employment='Employed full-time'
'''

# read a SQL query using pandas and create a dataframe
df_sql = pd.read_sql_query(sql, engine, index_col='Respondent')
df_sql.head()
# Out:
#                                 MainBranch   Age CompFreq  ConvertedComp  \
# Respondent
# 8           I am a developer by profession  36.0   Yearly       116000.0
# 10          I am a developer by profession  22.0   Yearly        32315.0
# 11          I am a developer by profession  23.0   Yearly        40070.0
# 14          I am a developer by profession  27.0   Yearly        66000.0
# 17          I am a developer by profession  25.0   Yearly        79000.0
#
#                    Country                                          EdLevel  \
# Respondent
# 8            United States     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 10          United Kingdom  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 11          United Kingdom     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 14           United States              Associate degree (A.A., A.S., etc.)
# 17           United States     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
# ...

# %% [markdown]
# **MainBranch ->** Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."<br>
# **Age** -> What is your age (in years)? If you prefer not to answer, you may leave this question blank.
# **CompFreq ->** Is that compensation weekly, monthly, or yearly?<br>
# **ConvertedComp ->** Salary converted to annual USD salaries using the exchange rate on 2020-02-19, assuming 12 working months and 50 working weeks.<br>
# **Country ->** Where do you live?<br>
# **EdLevel ->** Which of the following best describes the highest level of formal education that you’ve completed?<br>
# ****Employment ->** Which of the following best describes your current employment status?<br>
# **JobSat ->** How satisfied are you with your current job? (If you work multiple jobs, answer for the one you spend the most hours on.)<br>
# **LanguageWorkedWith ->** Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)<br>
# **OpSys ->** What is the primary operating system in which you work?<br>
# **UndergradMajor ->** What was your primary field of study?<br>
# **YearsCode ->** Including any education, how many years have you been coding in total?<br>
# **YearsCodePro ->** NOT including education, how many years have you coded professionally (as a part of your work)?

# %%
df_sql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14747 entries, 8 to 65629
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MainBranch          14747 non-null  object
#  1   Age                 13453 non-null  float64
#  2   CompFreq            14747 non-null  object
#  3   ConvertedComp       14297 non-null  float64
#  4   Country             14747 non-null  object
#  5   EdLevel             14747 non-null  object
#  6   Employment          14747 non-null  object
#  7   JobSat              14747 non-null  object
#  8   LanguageWorkedWith  14666 non-null  object
#  9   OpSys               14747 non-null  object
#  10  OrgSize             14747 non-null  object
#  11  UndergradMajor      14747 non-null  object
#  12  YearsCode           14707 non-null  float64
#  13  YearsCodePro        14709 non-null  float64
# dtypes: float64(4), object(10)
# memory usage: 1.7+ MB

# %% [markdown]
# <a id='3'></a>
# <div class="alert alert-block alert-danger">
#    <h2>
#     3 Data Preprocessing
#     </h2>
# </div>

# %%
# Make a copy of the dataframe
df = df_sql.copy()

# %%
# drop nan values in the LanguageWorkedWith column before searching 'Python'
df.dropna(subset=['LanguageWorkedWith'], inplace=True)

# filter rows containing professional software developers who know Python
df = df[df['LanguageWorkedWith'].str.contains('Python')]

# %%
# Since all the programmers in the table are professional and working full time, each of them knows python 
# and their salaries are paid annually, the related columns have been removed.
cols = df_sql.columns.to_list()
for i in ['MainBranch', 'CompFreq', 'Employment', 'LanguageWorkedWith']:
    cols.remove(i)
df = df_sql[cols].copy()
df.head()
# Out:
#              Age  ConvertedComp         Country  \
# Respondent
# 8           36.0       116000.0   United States
# 10          22.0        32315.0  United Kingdom
# 11          23.0        40070.0  United Kingdom
# 14          27.0        66000.0   United States
# 17          25.0        79000.0   United States
#
#                                                     EdLevel  \
# Respondent
# 8              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 10          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 11             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 14                      Associate degree (A.A., A.S., etc.)
# 17             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                            JobSat        OpSys                   OrgSize  \
# Respondent
# 8           Slightly dissatisfied  Linux-based        20 to 99 employees
# 10                 Very satisfied      Windows          2 to 9 employees
# ...

# %%
# create a df with categorical columns
df_cat = df.select_dtypes('object')
print('df_cat shape ',df_cat.shape)
# create a df with numeric columns
df_num = df.select_dtypes(['int64','float64'])
print('df_num shape ',df_num.shape)
# Out:
# df_cat shape  (14747, 6)
# df_num shape  (14747, 4)

# %%
# Encode categorical columns with value between 0 and the number of items-1
cols_encoded = {}

columns_info = []
for col in df_cat:
    each_col_info = []
    
    # number of unique values
    unique_vals = df_cat[col].value_counts(dropna=False).index.to_list()
    nr_values = len(unique_vals)
    
    cols_encoded[col] = []
    # get the unique_value and count from iterable list object in the for loop
    for i, j in enumerate(unique_vals):
        # add each unique value and count to the dictionary
        cols_encoded[col].append({i:j})
        # replace each unique value with the count to encode 
        df_cat[col].replace(j, str(i), inplace=True)

    # add each column's name, Number of uniques, and Uniques to the each_col_info list
    each_col_info.append(col)
    each_col_info.append(nr_values)
    each_col_info.append(unique_vals)
    # add the list with each column info to the columns_info list
    columns_info.append(each_col_info)

# create a dataframe using the columns_info list and sort it by 'Number of uniques' column
df_values_number = pd.DataFrame(columns_info, columns=['Feature', 'Number of uniques', 'Uniques'])
df_values_number.sort_values(by='Number of uniques', inplace=True)
df_values_number.reset_index(drop=True, inplace=True)
df_values_number
# Out:
#           Feature  Number of uniques  \
# 0           OpSys                  4
# 1          JobSat                  5
# 2         EdLevel                  6
# 3         OrgSize                  9
# 4  UndergradMajor                 12
# 5         Country                110
#
#                                              Uniques
# 0                 [Windows, MacOS, Linux-based, BSD]
# 1  [Very satisfied, Slightly satisfied, Slightly ...
# 2  [Bachelor’s degree (B.A., B.S., B.Eng., etc.),...
# 3  [100 to 499 employees, 20 to 99 employees, 10,...
# 4  [Computer science, computer engineering, or so...
# 5  [United States, United Kingdom, India, Germany...

# %%
# concat the encoded categorical dataframe and the numerical dataframe
df = pd.concat([df_num, df_cat], axis=1)

# Move the dependent column to the end
cols = df.columns.to_list()
cols.remove('ConvertedComp')
cols.append('ConvertedComp')
df = df[cols]
df.head()
# Out:
#              Age  YearsCode  YearsCodePro Country EdLevel JobSat OpSys  \
# Respondent
# 8           36.0       17.0          13.0       0       0      2     2
# 10          22.0        8.0           4.0       1       1      0     0
# 11          23.0       10.0           2.0       1       0      2     0
# 14          27.0        5.0           1.0       0       3      1     0
# 17          25.0        7.0           3.0       0       0      2     0
#
#            OrgSize UndergradMajor  ConvertedComp
# Respondent
# 8                1              0       116000.0
# 10               6              4        32315.0
# 11               2              0        40070.0
# 14               0              0        66000.0
# 17               1              0        79000.0

# %% [markdown]
# <a id='31'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         3.1 Investigate all the elements within each Feature
#    </h3>
# </div>

# %%
# Draw a matrix of scatter plots to understand the correlation among the features
axes = pd.plotting.scatter_matrix(df, alpha=0.7, figsize=(14, 10), diagonal='kde')
for ax in axes.flatten():
    ax.xaxis.label.set_rotation(0)
    ax.yaxis.label.set_rotation(0)
    ax.yaxis.label.set_ha('right')
    ax.set_xticks(())
    ax.set_yticks(())

plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.show()

# %%
def subplot_graph(df, bar=None, hist=None, scatter=None):
    # the number of features that will be used to create a subplot
    num_cols = len(bar + hist + scatter)
    cols = 0
    rows = 0
    
    # Number of rows/columns of the subplot grid. The max number of columns will be 3.
    if num_cols < 4:
        rows = 1
        cols = num_cols
    else:
        rows = math.ceil(num_cols/3)
        cols = 3

    # create a figure and a grid of subplots
    fig, axes = plt.subplots(rows, cols, figsize=(16, 4*rows))

    sub_rows = 0
    sub_cols = 0 
    
    # Make a bar plot.
    if bar:
        for f in bar:
            # the number of the columns will be restricted to 3.
            if sub_cols > cols-1:
                sub_cols = 0
                sub_rows += 1
                
            df_bar = df[f].value_counts()
            # the x coordinates of the bars
            x = list(df_bar.index)
            # the heights of the bars
            y = list(df_bar.values)
            try:
                # if the number of the features is less than 3
                axes[sub_cols].bar(x, y, label='0', color='firebrick')
                axes[sub_cols].set_title(f)
            except:
                axes[sub_rows, sub_cols].bar(x, y, label='0', color='firebrick')
                axes[sub_rows, sub_cols].set_title(f)
            sub_cols += 1
    
    # Make a histogram plot.
    if hist:
        for f in hist:
            if sub_cols > cols-1:
                sub_cols = 0
                sub_rows += 1
            
            sigma = df[f].dropna().std()
            mu = df[f].dropna().mean()
            num_bins = 20
            x = mu + sigma * np.random.randn(1000)
            try:
                n, bins, patches = axes[sub_cols].hist(df[f], num_bins, density=True, color='green', 
                                                       stacked=True, alpha=0.75)
                y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
                    np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
                axes[sub_cols].plot(bins, y, '--', color ='black')
                axes[sub_cols].set_title(f)
            except:
                n, bins, patches = axes[sub_rows, sub_cols].hist(df[f], num_bins, density=True, stacked=True,
                                                                 color='green', alpha=0.75)
                y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
                    np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
                axes[sub_rows, sub_cols].plot(bins, y, '--', color ='black')
                axes[sub_rows, sub_cols].set_title(f)
            sub_cols += 1
    
    # Make a scatter plot.
    if scatter:
        for f in scatter:
            if sub_cols > cols-1:
                sub_cols = 0
                sub_rows += 1
            
            x = list(df[f].index)
            y = list(df[f].values)
            try:
                axes[sub_cols].scatter(x, y, color ='blue')
                axes[sub_cols].set_title(f)
            except:
                axes[sub_rows, sub_cols].scatter(x, y, color ='blue')
                axes[sub_rows, sub_cols].set_title(f)
                
            sub_cols += 1

    fig.tight_layout()
    fig.show()

# %%
bar = df_cat.columns.to_list()
hist = ['Age', 'YearsCode', 'YearsCodePro']
scatter = ['ConvertedComp']
subplot_graph(df, bar, hist, scatter)

# %% [markdown]
# <a id='32'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         3.2 Missing Values
#    </h3>
# </div>

# %%
df.shape
# Out:
# (14747, 10)

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.heatmap(data=df.isnull(),cmap="viridis")
plt.show()

# %%
nan_values = pd.DataFrame(df.isnull().sum().sort_values(ascending=False))
nan_values = nan_values[nan_values.iloc[:,0]>0]

fig, ax = plt.subplots(figsize = (16, 6))
cmap = plt.get_cmap("RdBu")
ax.bar(nan_values.index, nan_values.iloc[:,0], color=cmap(nan_values.iloc[:,0]))
plt.xticks(rotation=30)
plt.show()

# %%
# remove rows where the columns have nan values
ind = df[df[['Age', 'YearsCode', 'YearsCodePro', 'ConvertedComp']].isna().all(axis=1)].index
df.drop(ind, axis=0, inplace=True)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         3.2.1 YearsCodePro
#     </h4>
# </div>

# %%
df['YearsCodePro'].value_counts(dropna=False).head()
# Out:
# 3.0    1388
# 5.0    1309
# 2.0    1222
# 4.0    1200
# 6.0     965
# Name: YearsCodePro, dtype: int64

# %%
df_dep_nan = df[df['YearsCodePro'].isna()]
df_dep_nan.head()
# Out:
#              Age  YearsCode  YearsCodePro Country EdLevel JobSat OpSys  \
# Respondent
# 2281         NaN       18.0           NaN       0       0      4     0
# 2560        29.0        NaN           NaN       2       1      1     0
# 2945         NaN       30.0           NaN       4       0      2     2
# 5318        39.0       22.0           NaN      42       0      0     2
# 5775         NaN       14.0           NaN       2       0      1     2
#
#            OrgSize UndergradMajor  ConvertedComp
# Respondent
# 2281             0              0            NaN
# 2560             2              0        27923.0
# 2945             5              0       150000.0
# 5318             6              2        23750.0
# 5775             7              0            NaN

# %%
def predict_nan(df, dependent_col, selected_col, *argv):
    # create a dataframe without nan values. This df will be used as X_train and y_train
    df_notnan = df.dropna(how='any')

    # create a dataframe with nan values using the dependent feature
    # This df will be used as X_test.
    df_dep_nan = df[df[dependent_col].isna()]
    # remove the nan values in the other features (Note: argv and (selected_col,) are tuples)
    df_dep_nan.dropna(subset=argv + (selected_col,), how='any', inplace=True)
    
    # The first 10000 rows will be evaluated as X_train and y_train
    X_train = df_notnan.drop([dependent_col], axis=1).iloc[:10000, :]
    y_train = df_notnan[dependent_col][:10000]
    
    # Since the dependent feature will be predicted, drop it from the dataframe
    X_test = df_dep_nan.drop([dependent_col], axis=1)
    
    # Random Forest Classifier will be used for prediction
    rfModel = RandomForestClassifier()
    rfModel.fit(X_train, y_train)
    generatedValues = rfModel.predict(X_test)
    
    # return the index numbers of rows with nan and predicted values
    ind = df_dep_nan.index
    rounded_generatedValues = np.round(generatedValues, 0)

    return ind, rounded_generatedValues

# %%
# the nan values in the 'YearsCodePro' column will be predicted 
# using 'ConvertedComp', 'Age', 'YearsCode' features
ind, generatedValues = predict_nan(df, 'YearsCodePro', 'ConvertedComp', 'Age', 'YearsCode')
df.loc[ind,'YearsCodePro'] = np.round(generatedValues, 0)

# %%
# the nan values in the 'YearsCodePro' column will be predicted 
# using 'ConvertedComp', 'YearsCode' features
df_2 = df.drop('Age', axis=1)
ind, generatedValues = predict_nan(df_2, 'YearsCodePro', 'ConvertedComp', 'YearsCode')
df.loc[ind,'YearsCodePro'] = np.round(generatedValues, 0)

# %%
# the nan values in the 'YearsCodePro' column will be predicted 
# using 'ConvertedComp', 'Age' features
df_3 = df.drop('YearsCode', axis=1)
ind, generatedValues = predict_nan(df_3, 'YearsCodePro', 'ConvertedComp', 'Age')
df.loc[ind,'YearsCodePro'] = np.round(generatedValues, 0)

# %%
# the nan values in the 'YearsCodePro' column will be predicted 
# using 'Age', 'YearsCode' features
df_4 = df.drop('ConvertedComp', axis=1)
ind, generatedValues = predict_nan(df_4, 'YearsCodePro', 'YearsCode', 'Age')
df.loc[ind,'YearsCodePro'] = np.round(generatedValues, 0)

# %%
# get the remaining nan values in the 'YearsCodePro' column, but not in the 'YearsCode'
df_5 = df[df['YearsCodePro'].isna()]
df_5 = df_5[df_5['YearsCode'].notna()]
df_5
# Out:
#             Age  YearsCode  YearsCodePro Country EdLevel JobSat OpSys OrgSize  \
# Respondent
# 2281        NaN       18.0           NaN       0       0      4     0       0
# 5775        NaN       14.0           NaN       2       0      1     2       7
# 8030        NaN       15.0           NaN       2       1      1     2       1
# 29396       NaN       20.0           NaN      33       4      3     2       4
#
#            UndergradMajor  ConvertedComp
# Respondent
# 2281                    0            NaN
# 5775                    0            NaN
# 8030                    0            NaN
# 29396                   0            NaN

# %%
# replace the remaining nan values with the mean of the 'YearsCode' data
ind = df_5.index
for i in ind:
    df.loc[i, 'YearsCodePro'] = round(df_5['YearsCode'].mean(), 0)

# %%
df.isna().sum()
# Out:
# Age               1290
# YearsCode           36
# YearsCodePro         5
# Country              0
# EdLevel              0
# JobSat               0
# OpSys                0
# OrgSize              0
# UndergradMajor       0
# ConvertedComp      446
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         3.2.2 ConvertedComp
#     </h4>
# </div>

# %%
# the nan values in the 'ConvertedComp' column will be predicted 
# using 'YearsCodePro', 'Age', 'YearsCode' features
ind, generatedValues = predict_nan(df, 'ConvertedComp', 'YearsCodePro', 'Age', 'YearsCode')
df.loc[ind,'ConvertedComp'] = np.round(generatedValues, 0)

# %%
# the nan values in the 'ConvertedComp' column will be predicted 
# using 'YearsCodePro', 'YearsCode' features
df_CC_2 = df.drop('Age', axis=1)
ind, generatedValues = predict_nan(df_CC_2, 'ConvertedComp', 'YearsCodePro', 'YearsCode')
df.loc[ind,'ConvertedComp'] = np.round(generatedValues, 0)

# %%
df.isna().sum()
# Out:
# Age               1290
# YearsCode           36
# YearsCodePro         5
# Country              0
# EdLevel              0
# JobSat               0
# OpSys                0
# OrgSize              0
# UndergradMajor       0
# ConvertedComp        3
# dtype: int64

# %%
# drop the remaining nan values in the 'ConvertedComp' column
ind = df[df['ConvertedComp'].isna()].index.to_list()
df.drop(ind, axis=0, inplace=True)

# %%
df.isna().sum()
# Out:
# Age               1289
# YearsCode           33
# YearsCodePro         3
# Country              0
# EdLevel              0
# JobSat               0
# OpSys                0
# OrgSize              0
# UndergradMajor       0
# ConvertedComp        0
# dtype: int64

# %%
# drop the remaining nan values in the 'YearsCodePro' column
ind = df[df['YearsCodePro'].isna()].index.to_list()
df.drop(ind, axis=0, inplace=True)

# %%
df.isna().sum()
# Out:
# Age               1286
# YearsCode           30
# YearsCodePro         0
# Country              0
# EdLevel              0
# JobSat               0
# OpSys                0
# OrgSize              0
# UndergradMajor       0
# ConvertedComp        0
# dtype: int64

# %% [markdown]
# <a id='33'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         3.3 Drop Features Using Pearson Correlation
#    </h3>
# </div>

# %%
def create_heatmap(hm, figsize=(12, 8)):
    fig, ax = plt.subplots(figsize=figsize)

    im = ax.imshow(hm, 
    #                vmin=0, vmax=10, 
                   cmap='viridis', aspect='auto')

    # Create colorbar
    cbar = ax.figure.colorbar(im, ax=ax)

    # We want to show all ticks...
    ax.set_xticks(np.arange(len(hm.columns)))
    ax.set_yticks(np.arange(len(hm.columns)))
    # ... and label them with the respective list entries
    ax.set_xticklabels(hm.columns)
    ax.set_yticklabels(hm.columns)

    # Turn spines off and create white grid.
    ax.spines[:].set_visible(False)
    ax.set_xticks(np.arange(hm.shape[1]+1)-.5, minor=True)
    ax.set_yticks(np.arange(hm.shape[0]+1)-.5, minor=True)
    ax.grid(which="minor", color="w", linestyle='-', linewidth=3)
    ax.tick_params(which="minor", bottom=False, left=False)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    for i in range(len(hm.columns)):
        for j in range(len(hm.columns)):
            hm_val = round(hm.values[i, j], 2)
            if hm_val > 0.85:
                text = ax.text(j, i, hm_val,
                               ha="center", va="center", color="black", size=16)
            else:
                text = ax.text(j, i, hm_val,
                               ha="center", va="center", color="w", size=16)

    fig.tight_layout()
    plt.show()

# %%
# select highly correlated features
hm = df.corr()
create_heatmap(hm)

# %%
# 'YearsCodePro' is highly correlated with 'Age', 'YearsCode' features
# Therefore, 'Age', 'YearsCode' features will not be used in the regression
df.drop(['Age', 'YearsCode'], axis=1, inplace=True)

# %%
# convert all values of the df to integer
df = df.astype(int)

# %%
df.head()
# Out:
#             YearsCodePro  Country  EdLevel  JobSat  OpSys  OrgSize  \
# Respondent
# 8                     13        0        0       2      2        1
# 10                     4        1        1       0      0        6
# 11                     2        1        0       2      0        2
# 14                     1        0        3       1      0        0
# 17                     3        0        0       2      0        1
#
#             UndergradMajor  ConvertedComp
# Respondent
# 8                        0         116000
# 10                       4          32315
# 11                       0          40070
# 14                       0          66000
# 17                       0          79000

# %% [markdown]
# <a id='34'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         3.4 Drop Outliers
#    </h3>
# </div>

# %%
print('number of columns with missing values',df.isnull().any().sum())
# Out:
# number of columns with missing values 0

# %%
def box_plot(df, label):
    fig, ax = plt.subplots(figsize = (10, 1))
    # rectangular box plot
    bplot = ax.boxplot(df,
                           vert=False,  # vertical box alignment
                           notch=True,  # notch shape
                           patch_artist=True,  # fill with color
                           labels=[label]  # will be used to label x-ticks
                          )
    # fill with colors
    colors = ['pink', 'lightblue', 'lightgreen']
    for box in bplot:
        for patch, color in zip(bplot['boxes'], colors):
            patch.set_facecolor(color)


    whiskers_1 = bplot['whiskers'][0].get_xdata()[1]
    whiskers_2 = bplot['whiskers'][0].get_xdata()[0]
    median = bplot['medians'][0].get_xdata()[0]
    whiskers_3 = bplot['whiskers'][1].get_xdata()[0]
    whiskers_4 = bplot['whiskers'][1].get_xdata()[1]
    
    ax.text(whiskers_1, 1.15, f"{whiskers_1}", ha='center', va='center', color='b', size=13)
    ax.text(whiskers_2, 1.25, f"{whiskers_2}", ha='center', va='center', color='b', size=13)
    ax.text(median, 0.7, f"{median}", ha='center', va='center', color='b', size=13)
    ax.text(whiskers_3, 1.25, f"{whiskers_3}", ha='center', va='center', color='b', size=13)
    ax.text(whiskers_4, 1.15, f"{whiskers_4}", ha='center', va='center', color='b', size=13)


    ax.xaxis.grid(True)
    plt.show()

    outliers = bplot['fliers'][0].get_xdata()
#     print(sorted(outliers))

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         YearsCodePro
#     </h4>
# </div>

# %%
box_plot(df['YearsCodePro'], 'YearsCodePro')

# %%
# get the index of outliers
outliers_index = df[df['YearsCodePro'] > 40].index
outliers_index
# Out:
# Int64Index([ 1824,  2047,  2638,  2904,  3083,  3485,  3496,  5467,  5549,
#              5782, 14514, 17765, 18314, 23055, 24814, 27547, 30223, 32537,
#             34392, 34525, 34527, 34628, 34636, 34677, 36003, 42977, 43695,
#             46707, 47092, 47107, 48359, 49623, 50272, 51962, 52067, 53692,
#             54315, 59134, 60374],
#            dtype='int64', name='Respondent')

# %%
# drop outliers
df = df.drop(outliers_index, axis=0)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         ConvertedComp
#     </h4>
# </div>

# %%
box_plot(df['ConvertedComp'], 'ConvertedComp')

# %%
# get the index of outliers
outliers_index = df[df['ConvertedComp'] > 200000].index
len(outliers_index)
# Out:
# 581

# %%
# drop outliers
df = df.drop(outliers_index, axis=0)

# %% [markdown]
# <a id='34'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         3.4 Check zero variance features
#    </h3>
# </div>

# %%
# It will remove zero variance features
from sklearn.feature_selection import VarianceThreshold
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(df)

# get_support() -> Get a mask, or integer index, of the features selected
constant_columns = [column for column in df.columns
                    if column not in df.columns[var_thres.get_support()]]
constant_columns
# Out:
# []

# %%
# df.to_csv('from_sql_to_df.csv', index=False)

# %%
# df = pd.read_csv('from_sql_to_df.csv')
# df.head()

# %% [markdown]
# <a id='4'></a>
# <div class="alert alert-block alert-danger">
#    <h2>
#     4. Regressions and Results
#     </h2>
# </div>

# %% [markdown]
# <a id='41'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         4.1 Separate the dataset into train and test
#    </h3>
# </div>

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# scale_col = ['YearsCodePro', 'Country', 'EdLevel', 'JobSat', 'OpSys', 'OrgSize', 'UndergradMajor']
# df[scale_col] = scaler.fit_transform(df[scale_col])

# %%
# Split the dataframe into random train and test subsets
X = df[['YearsCodePro', 'Country', 'EdLevel', 'JobSat', 'OpSys', 'OrgSize', 'UndergradMajor']]
y = df['ConvertedComp']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (11293, 7)
# (2824, 7)
# (11293,)
# (2824,)

# %% [markdown]
# <a id='42'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         4.2 Running Machine Learning Models
#    </h3>
# </div>

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

def evaluate_model(model, X_train, X_test, y_train, y_test):
    # Return the coefficient of determination R2 of the prediction

    # We will run the model with 10 different sets and we will get 10 results
    cv = KFold(n_splits=10, random_state=0, shuffle=True)
    # Applying Cross Validation to solve possible overfitting problem
    scores_train = cross_val_score(model, X_train, y_train, scoring='r2', cv=cv)
    r2_train = scores_train.mean()
    scores_test = cross_val_score(model, X_test, y_test, scoring='r2', cv=cv)
    r2_test = scores_test.mean()

#     r2_train = model.score(X_train, y_train)
#     r2_test = model.score(X_test, y_test)
    print('The Accuracy  on the training dataset is: {:.1%}'.format(r2_train))
    print('The Accuracy  on the testing dataset is: {:.1%}'.format(r2_test))
    
    print("")
    
    # Mean squared error (MSE) regression loss
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    MSE_train = math.sqrt(mean_squared_error(y_train, y_train_pred))
    MSE_test = math.sqrt(mean_squared_error(y_test, y_test_pred))
    print('The RMSE  on the training dataset is: {:.8}'.format(MSE_train))
    print('The RMSE  on the testing dataset is: {:.8}'.format(MSE_test))
    
    return r2_train, r2_test, MSE_train, MSE_test

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         4.2.1 LinearRegression
#     </h4>
# </div>

# %%
from sklearn.linear_model import LinearRegression
linear = LinearRegression()
linear.fit(X_train, y_train)

lin_r2_train, lin_r2_test, lin_MSE_train, lin_MSE_test = evaluate_model(linear, X_train, X_test, y_train, 
                                                                        y_test)
# Out:
# The Accuracy  on the training dataset is: 22.4%
# The Accuracy  on the testing dataset is: 22.7%
#
# The RMSE  on the training dataset is: 38603.659
# The RMSE  on the testing dataset is: 38551.686

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         4.2.2 PolynomialFeatures
#     </h4>
# </div>

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly = PolynomialFeatures(degree=3)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.fit_transform(X_test)

lm_poly = LinearRegression()
lm_poly.fit(X_train_poly, y_train)

poly_r2_train, poly_r2_test, poly_MSE_train, poly_MSE_test = evaluate_model(lm_poly, X_train_poly, 
                                                                            X_test_poly, y_train, y_test)
# Out:
# The Accuracy  on the training dataset is: 34.8%
# The Accuracy  on the testing dataset is: 29.4%
#
# The RMSE  on the training dataset is: 34859.68
# The RMSE  on the testing dataset is: 35173.125

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         4.2.2 DecisionTreeRegressor
#     </h4>
# </div>

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
dtr_r2_train, dtr_r2_test, dtr_MSE_train, dtr_MSE_test = evaluate_model(dt, X_train, X_test, y_train, 
                                                                        y_test)
# Out:
# The Accuracy  on the training dataset is: 33.9%
# The Accuracy  on the testing dataset is: 19.8%
#
# The RMSE  on the training dataset is: 8927.5818
# The RMSE  on the testing dataset is: 36303.038

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         4.2.4 Ridge, Lasso
#     </h4>
# </div>

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train, y_train)
ridge_r2_train, ridge_r2_test, ridge_MSE_train, ridge_MSE_test = evaluate_model(ridge, X_train, X_test, 
                                                                                y_train, y_test)
# Out:
# The Accuracy  on the training dataset is: 22.4%
# The Accuracy  on the testing dataset is: 22.7%
#
# The RMSE  on the training dataset is: 38603.659
# The RMSE  on the testing dataset is: 38551.69

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(X_train, y_train)
lasso_r2_train, lasso_r2_test, lasso_MSE_train, lasso_MSE_test = evaluate_model(lasso, X_train, X_test, 
                                                                                y_train, y_test)
# Out:
# The Accuracy  on the training dataset is: 22.4%
# The Accuracy  on the testing dataset is: 22.7%
#
# The RMSE  on the training dataset is: 38603.659
# The RMSE  on the testing dataset is: 38551.695

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         4.2.6 GradientBoostingRegressor
#     </h4>
# </div>

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(X_train, y_train)
gbr_r2_train, gbr_r2_test, gbr_MSE_train, gbr_MSE_test = evaluate_model(gbr, X_train, X_test, y_train, 
                                                                        y_test)
# Out:
# The Accuracy  on the training dataset is: 64.9%
# The Accuracy  on the testing dataset is: 62.0%
#
# The RMSE  on the training dataset is: 25498.842
# The RMSE  on the testing dataset is: 26456.895

# %%
# from sklearn.ensemble import GradientBoostingRegressor
# gbr = GradientBoostingRegressor(alpha=0.9,
#                                       learning_rate=0.01, loss='huber',
#                                       max_depth=13, max_features=0.1, min_samples_split=110,
#                                       n_estimators=10000, n_iter_no_change=100, random_state=42)
# gbr_result = gbr.fit(X_train, y_train)
# gbr_r2_train, gbr_r2_test, gbr_MSE_train, gbr_MSE_test = evaluate_model(gbr)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         4.2.7 Model_Selection - Final
#     </h4>
# </div>

# %%
# The GradientBoostingRegressor model with the highest R2 value has been selected.
df_models_acc = pd.DataFrame({
    'Model': ['lr', 'poly', 'dt', 'ridge', 'lasso', 'gbr'],
    'R2_Train': [lin_r2_train, poly_r2_train, dtr_r2_train, ridge_r2_train, 
                       lasso_r2_train, gbr_r2_train],
    'R2_Test': [lin_r2_test, poly_r2_test, dtr_r2_test, ridge_r2_test, 
                       lasso_r2_test, gbr_r2_test],
    'RMSE_Train': [lin_MSE_train, poly_MSE_train, dtr_MSE_train, ridge_MSE_train, 
                       lasso_MSE_train, gbr_MSE_train],
    'RMSE_Test': [lin_MSE_test, poly_MSE_test, dtr_MSE_test, ridge_MSE_test, 
                       lasso_MSE_test, gbr_MSE_test],
})
df_models_acc.sort_values(by='R2_Test', ascending=False)
# Out:
#    Model  R2_Train   R2_Test    RMSE_Train     RMSE_Test
# 5    gbr  0.649489  0.620013  25498.842221  26456.894859
# 1   poly  0.347506  0.294277  34859.679522  35173.125301
# 3  ridge  0.223679  0.227130  38603.658664  38551.689504
# 4  lasso  0.223679  0.227129  38603.658709  38551.694565
# 0     lr  0.223679  0.227129  38603.658659  38551.685530
# 2     dt  0.338945  0.197818   8927.581777  36303.038158

# %% [markdown]
# <a id='43'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         4.3 Accuracy improvement of the selected model
#    </h3>
# </div>

# %%
model = GradientBoostingRegressor()
model.fit(X_train, y_train)
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
gbr_r2_train, gbr_r2_test, gbr_MSE_train, gbr_MSE_test = evaluate_model(model, X_train, X_test, y_train, 
                                                                        y_test)
# Out:
# The Accuracy  on the training dataset is: 64.9%
# The Accuracy  on the testing dataset is: 62.0%
#
# The RMSE  on the training dataset is: 25498.842
# The RMSE  on the testing dataset is: 26456.895

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         4.3.1 Accuracy improvement_1
#     </h4>
# </div>

# %%
# scatter plot has been used to explore the relationship between y_train and y_residual

x = y_train
y_residual = y_pred_train - y_train

fig, ax = plt.subplots(figsize = (16, 8))

ax.scatter(x, y_residual, color ='blue', alpha=0.5)
ax.axhline(y=0, color='r', linestyle='--', linewidth=2)
# a horizontal span (rectangle) across the axis has been added to point out the suitable residuals 
ax.axhspan(-35000, 35000, color='green', facecolor='0.2', alpha=0.5)

ax.set_xlabel('Actuals', fontsize=18)
ax.set_ylabel('Residuals', fontsize=18)
ax.set_title("Actuals Vs Residuals", fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
fig.show()

# %%
# the data causing unsuitable residuals have been removed from the dataframe
drop_rows = y_residual[(y_residual > 35000) | (y_residual < -35000)].index
df_1 = df.drop(drop_rows, axis=0).reset_index(drop=True)

# the selected model has been run again
X1 = df_1[df_1.columns[:-1]].values
y1 = df_1[df_1.columns[-1]].astype(int)
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=1)

model1 = GradientBoostingRegressor()
model1.fit(X_train1, y_train1)
y_pred_train1 = model1.predict(X_train1)
y_pred_test1 = model1.predict(X_test1)

# Model Accuracy
gbr_r2_train, gbr_r2_test, gbr_MSE_train, gbr_MSE_test = evaluate_model(model, X_train, X_test, y_train, 
                                                                        y_test)
print('=======')
# The accuracy has been increased by almost 12% more
gbr_r2_train2, gbr_r2_test2, gbr_MSE_train2, gbr_MSE_test2 = evaluate_model(model1, X_train1, X_test1, 
                                                                            y_train1, y_test1)
# Out:
# The Accuracy  on the training dataset is: 64.9%
# The Accuracy  on the testing dataset is: 62.0%
#
# The RMSE  on the training dataset is: 25498.842
# The RMSE  on the testing dataset is: 26456.895
# ...
# The Accuracy  on the training dataset is: 76.4%
# The Accuracy  on the testing dataset is: 77.5%
#
# The RMSE  on the training dataset is: 18582.704
# The RMSE  on the testing dataset is: 18461.253

# %%
# scatter plot has been used again to see the changes in the residuals
from sklearn.metrics import r2_score
fig, ax = plt.subplots(figsize = (16, 8))

ax.scatter(y_train1, y_pred_train1, color ='blue', alpha=0.5)

z = np.polyfit(y_train1, y_pred_train1, 1)
y_hat = np.poly1d(z)(y_train1)

plt.plot(y_train1 , y_hat, "r--", linewidth=2)

text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(y_pred_train1,y_hat):0.3f}$"
plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     fontsize=14, verticalalignment='top')


ax.set_xlabel('Actual', fontsize=18)
ax.set_ylabel('Predicted', fontsize=18)
ax.set_title("Actuals Vs Predicted", fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         4.3.2 Accuracy improvement_2
#     </h4>
# </div>

# %%
# some of the data has been removed to increase the accuracy more
df_2 = df_1[(df_1['ConvertedComp'] < 175000) & (df_1['ConvertedComp'] > 2000)]
len(df_2)
# Out:
# 12324

# %%
# the selected model has been run again
X2 = df_2[df_2.columns[:-1]].values
y2 = df_2[df_2.columns[-1]].astype(int)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.2, random_state=1)

model2 = GradientBoostingRegressor()
model2.fit(X_train2, y_train2)
y_pred_train2 = model2.predict(X_train2)
y_pred_test2 = model2.predict(X_test2)

# Model Accuracy
gbr_r2_train, gbr_r2_test, gbr_MSE_train, gbr_MSE_test = evaluate_model(model1, X_train1, X_test1, y_train1, 
                                                                        y_test1)
print('=======')
# The accuracy has been increased by almost 2% more
gbr_r2_train2, gbr_r2_test2, gbr_MSE_train2, gbr_MSE_test2 = evaluate_model(model2, X_train2, X_test2, y_train2, 
                                                                        y_test2)
# Out:
# The Accuracy  on the training dataset is: 76.4%
# The Accuracy  on the testing dataset is: 77.5%
#
# The RMSE  on the training dataset is: 18582.704
# The RMSE  on the testing dataset is: 18461.253
# ...
# The Accuracy  on the training dataset is: 78.1%
# The Accuracy  on the testing dataset is: 75.6%
#
# The RMSE  on the training dataset is: 17152.2
# The RMSE  on the testing dataset is: 17786.197

# %%
# scatter plot has been used again to see the changes in the residuals
from sklearn.metrics import r2_score
fig, ax = plt.subplots(figsize = (16, 8))

ax.scatter(y_train2, y_pred_train2, color ='blue', alpha=0.5)

z = np.polyfit(y_train2, y_pred_train2, 1)
y_hat = np.poly1d(z)(y_train2)

plt.plot(y_train2 , y_hat, "r--", linewidth=2)

text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(y_pred_train2,y_hat):0.3f}$"
plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     fontsize=14, verticalalignment='top')


ax.set_xlabel('Actual', fontsize=18)
ax.set_ylabel('Predicted', fontsize=18)
ax.set_title("Actuals Vs Predicted", fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         4.3.3 Accuracy improvement_3
#     </h4>
# </div>

# %%
current_cols = ['YearsCodePro', 'Country', 'EdLevel', 'JobSat', 'OpSys', 'OrgSize', 'UndergradMajor']
# Some features that have almost no effect on the accuracy have been removed to simplify the model.
df_3 = df_2[['YearsCodePro', 'Country', 'OpSys', 'OrgSize', 'ConvertedComp']]

X3 = df_3[df_3.columns[:-1]].values
y3 = df_3[df_3.columns[-1]].astype(int)

X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=0.2, random_state=1)

model3 = GradientBoostingRegressor()
model3.fit(X_train3, y_train3)
y_pred_train3 = model3.predict(X_train3)
y_pred_test3 = model3.predict(X_test3)

# Model Accuracy
gbr_r2_train, gbr_r2_test, gbr_MSE_train, gbr_MSE_test = evaluate_model(model2, X_train2, X_test2, y_train2, 
                                                                        y_test2)
print('=======')
# The accuracy has been decreased by almost 0.2%
gbr_r2_train2, gbr_r2_test2, gbr_MSE_train2, gbr_MSE_test2 = evaluate_model(model3, X_train3, X_test3, y_train3, 
                                                                        y_test3)
# Out:
# The Accuracy  on the training dataset is: 78.1%
# The Accuracy  on the testing dataset is: 75.7%
#
# The RMSE  on the training dataset is: 17152.2
# The RMSE  on the testing dataset is: 17786.197
# ...
# The Accuracy  on the training dataset is: 77.9%
# The Accuracy  on the testing dataset is: 75.9%
#
# The RMSE  on the training dataset is: 17388.977
# The RMSE  on the testing dataset is: 17852.843

# %%
# scatter plot has been used again to see the changes in the residuals
from sklearn.metrics import r2_score
fig, ax = plt.subplots(figsize = (16, 8))

ax.scatter(y_train3, y_pred_train3, color ='blue', alpha=0.5)

z = np.polyfit(y_train3, y_pred_train3, 1)
y_hat = np.poly1d(z)(y_train3)

plt.plot(y_train2 , y_hat, "r--", linewidth=2)

text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(y_pred_train3,y_hat):0.3f}$"
plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     fontsize=14, verticalalignment='top')


ax.set_xlabel('Actual', fontsize=18)
ax.set_ylabel('Predicted', fontsize=18)
ax.set_title("Actuals Vs Predicted", fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         4.3.4 Accuracy improvement_4
#     </h4>
# </div>

# %%
# scatter plot has been used to explore the relationship between y_train and y_residual

x_last = y_train3
y_residual_last = y_pred_train3 - y_train3

fig, ax = plt.subplots(figsize = (16, 8))

ax.scatter(x_last, y_residual_last, color ='blue', alpha=0.5)
ax.axhline(y=0, color='r', linestyle='--', linewidth=2)
# a horizontal span (rectangle) across the axis has been added to point out the suitable residuals 
ax.axhspan(-35000, 35000, color='green', facecolor='0.2', alpha=0.5)

ax.set_xlabel('Actuals', fontsize=18)
ax.set_ylabel('Residuals', fontsize=18)
ax.set_title("Actuals Vs Residuals", fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
fig.show()

# %%
drop_rows_last = y_residual_last[(y_residual_last > 35000) | (y_residual_last < -35000)].index
df_4 = df_3.drop(drop_rows_last, axis=0).reset_index(drop=True)

# %%
# the selected model has been run again
X4 = df_4[df_4.columns[:-1]].values
y4 = df_4[df_4.columns[-1]].astype(int)
X_train4, X_test4, y_train4, y_test4 = train_test_split(X4, y4, test_size=0.2, random_state=1)

model4 = GradientBoostingRegressor()
model4.fit(X_train4, y_train4)
y_pred_train4 = model4.predict(X_train4)
y_pred_test4 = model4.predict(X_test4)

# Model Accuracy
gbr_r2_train, gbr_r2_test, gbr_MSE_train, gbr_MSE_test = evaluate_model(model3, X_train3, X_test3, y_train3, 
                                                                        y_test3)
print('=======')
# The accuracy has been increased by almost 3% more
gbr_r2_train2, gbr_r2_test2, gbr_MSE_train2, gbr_MSE_test2 = evaluate_model(model4, X_train4, X_test4, 
                                                                            y_train4, y_test4)
# Out:
# The Accuracy  on the training dataset is: 77.9%
# The Accuracy  on the testing dataset is: 75.9%
#
# The RMSE  on the training dataset is: 17388.977
# The RMSE  on the testing dataset is: 17852.843
# ...
# The Accuracy  on the training dataset is: 81.5%
# The Accuracy  on the testing dataset is: 81.3%
#
# The RMSE  on the training dataset is: 15309.117
# The RMSE  on the testing dataset is: 15941.434

# %%
# scatter plot has been used again to see the changes in the residuals
from sklearn.metrics import r2_score
fig, ax = plt.subplots(figsize = (16, 8))

ax.scatter(y_train4, y_pred_train4, color ='blue', alpha=0.5)

z = np.polyfit(y_train4, y_pred_train4, 1)
y_hat = np.poly1d(z)(y_train4)

plt.plot(y_train4 , y_hat, "r--", linewidth=2)

text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(y_pred_train4, y_hat):0.3f}$"
plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     fontsize=14, verticalalignment='top')


ax.set_xlabel('Actual', fontsize=18)
ax.set_ylabel('Predicted', fontsize=18)
ax.set_title("Actuals Vs Predicted", fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h4>
#         4.3.5 Accuracy improvement_5
#     </h4>
# </div>

# %%
# scatter plot has been used to explore the relationship between y_train and y_residual

x_5 = y_train4
y_residual_5 = y_pred_train4 - y_train4

fig, ax = plt.subplots(figsize = (16, 8))

ax.scatter(x_5, y_residual_5, color ='blue', alpha=0.5)
ax.axhline(y=0, color='r', linestyle='--', linewidth=2)
# a horizontal span (rectangle) across the axis has been added to point out the suitable residuals 
ax.axhspan(-35000, 35000, color='green', facecolor='0.2', alpha=0.5)

ax.set_xlabel('Actuals', fontsize=18)
ax.set_ylabel('Residuals', fontsize=18)
ax.set_title("Actuals Vs Residuals", fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
fig.show()

# %%
drop_rows_5 = y_residual_5[(y_residual_5 > 35000) | (y_residual_5 < -35000)].index
len(drop_rows_5)
df_5 = df_4.drop(drop_rows_5, axis=0).reset_index(drop=True)

# %%
# the selected model has been run again
X5 = df_5[df_5.columns[:-1]].values
y5 = df_5[df_5.columns[-1]].astype(int)
X_train5, X_test5, y_train5, y_test5 = train_test_split(X5, y5, test_size=0.2, random_state=1)

model5 = GradientBoostingRegressor()
model5.fit(X_train5, y_train5)
y_pred_train5 = model5.predict(X_train5)
y_pred_test5 = model5.predict(X_test5)

# Model Accuracy
gbr_r2_train, gbr_r2_test, gbr_MSE_train, gbr_MSE_test = evaluate_model(model4, X_train4, X_test4, y_train4, 
                                                                        y_test4)
print('=======')
# The accuracy has been increased by almost 1% more
gbr_r2_train2, gbr_r2_test2, gbr_MSE_train2, gbr_MSE_test2 = evaluate_model(model5, X_train5, X_test5, 
                                                                            y_train5, y_test5)
# Out:
# The Accuracy  on the training dataset is: 81.5%
# The Accuracy  on the testing dataset is: 81.3%
#
# The RMSE  on the training dataset is: 15309.117
# The RMSE  on the testing dataset is: 15941.434
# ...
# The Accuracy  on the training dataset is: 82.7%
# The Accuracy  on the testing dataset is: 83.3%
#
# The RMSE  on the training dataset is: 14834.709
# The RMSE  on the testing dataset is: 14675.473

# %%
# scatter plot has been used again to see the changes in the residuals
from sklearn.metrics import r2_score
fig, ax = plt.subplots(figsize = (16, 8))

ax.scatter(y_train5, y_pred_train5, color ='blue', alpha=0.5)

z = np.polyfit(y_train5, y_pred_train5, 1)
y_hat = np.poly1d(z)(y_train5)

plt.plot(y_train5, y_hat, "r--", linewidth=2)

text = f"$y={z[0]:0.3f}\;x{z[1]:+0.3f}$\n$R^2 = {r2_score(y_pred_train5, y_hat):0.3f}$"
plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     fontsize=14, verticalalignment='top')


ax.set_xlabel('Actual', fontsize=18)
ax.set_ylabel('Predicted', fontsize=18)
ax.set_title("Actuals Vs Predicted", fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
fig.show()

# %% [markdown]
# <a id='5'></a>
# <div class="alert alert-block alert-danger">
#    <h2>
#     5. Making Predictions
#     </h2>
# </div>

# %%
df_pred = df_5.reset_index(drop=True)
df_pred.tail()
# Out:
#        YearsCodePro  Country  OpSys  OrgSize  ConvertedComp
# 11766            14        7      0        5          35672
# 11767            10        3      2        1          70264
# 11768             2        1      0        1          38778
# 11769             3       15      0        3          38670
# 11770             4        6      2        3          80172

# %%
# Variables
ind = 11769
print(df_pred.loc[ind, 'ConvertedComp'])
YearsCodePro = df_pred.iloc[ind, 0]
Country = df_pred.iloc[ind, 1]
OpSys = df_pred.iloc[ind, 2]
OrgSize = df_pred.iloc[ind, 3]

X_val = np.array([[YearsCodePro, Country, OpSys, OrgSize],])
X_val_lm = model5.predict(X_val)
pred = X_val_lm[0]
print('The predicted value is: {:.8}'.format(pred))
# Out:
# 38670
# The predicted value is: 45006.082

# %%
cols_encoded
# Out:
# {'Country': [{0: 'United States'},
#   {1: 'United Kingdom'},
#   {2: 'India'},
#   {3: 'Germany'},
#   {4: 'Canada'},
#   {5: 'France'},
#   {6: 'Australia'},
#   {7: 'Spain'},
#   {8: 'Netherlands'},
#   {9: 'Italy'},
#   {10: 'Norway'},
#   {11: 'Ireland'},
#   {12: 'Switzerland'},
#   {13: 'New Zealand'},
#   {14: 'Brazil'},
#   {15: 'Japan'},
#   {16: 'Austria'},
#   {17: 'Portugal'},
#   {18: 'Greece'},
#   {19: 'Poland'},
#   {20: 'Sweden'},
#   {21: 'Finland'},
#   {22: 'South Africa'},
#   {23: 'South Korea'},
#   {24: 'Taiwan'},
#   {25: 'Belgium'},
#   {26: 'Turkey'},
#   {27: 'Denmark'},
#   {28: 'Singapore'},
#   {29: 'Mexico'},
#   {30: 'Russian Federation'},
#   {31: 'Israel'},
#   {32: 'Malta'},
#   {33: 'China'},
#   {34: 'Bulgaria'},
#   {35: 'Romania'},
#   {36: 'Nigeria'},
#   {37: 'Cyprus'},
#   {38: 'Czech Republic'},
#   {39: 'Slovenia'},
#   {40: 'Argentina'},
#   {41: 'Pakistan'},
#   {42: 'Iran'},
#   {43: 'Bangladesh'},
#   {44: 'Republic of Korea'},
# ...

# %%
def inputs_to_be_predicted(YearsCodePro, country, OpSys, OrgSize):
    for i in range(0, len(cols_encoded['Country'])):
        if list(cols_encoded['Country'][i].values())[0] == country:
            Country = i

    for j in range(0, len(cols_encoded['OpSys'])):
        if list(cols_encoded['OpSys'][j].values())[0] == OpSys:
            OpSys = j

    for k in range(0, len(cols_encoded['OrgSize'])):
        if list(cols_encoded['OrgSize'][k].values())[0] == OrgSize:
            OrgSize = k

    X_val = np.array([[YearsCodePro, Country, OpSys, OrgSize],])
    X_val_lm = model5.predict(X_val)
    pred = X_val_lm[0]
    
    return pred

# %%
pred = inputs_to_be_predicted(2, 'Germany', 'Windows', '1,000 to 4,999 employees')
print('The predicted value is: {:.8}'.format(pred))
# Out:
# The predicted value is: 53838.68
