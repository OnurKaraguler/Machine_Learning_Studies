# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2>Table of Contents</h2>
# </div>

# %% [markdown]
# [Import Libraries](#1.0)<br>
# [Connect to the mysql database](#2.0)<br>
# [Load Data](#3.0)<br>
# [Dataframes to SQL](#4.0)<br>
# [Send the main dataframe replaced with index values](#5.0)<br>
# [Add comments into sql tables](#6.0)<br>
# [Add comments into columns in a sql table](#7.0)<br>

# %% [markdown]
# <a id='1.0'></a>
# <div class="alert alert-block alert-danger">
# <h2>Import Libraries</h2>
# </div>

# %%
import warnings
warnings.filterwarnings('ignore')

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # ignore information messages

import math
import numpy as np 
import pandas as pd
# display all of the columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# <a id='2.0'></a>
# <div class="alert alert-block alert-danger">
# <h2>Connect to the mysql database</h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#         Read the cvc file with username and password
# </div>

# %%
mysql_user_pass = pd.read_csv('../../../mysql_user_pass.csv', index_col=0)
username = mysql_user_pass['mysql_user'][0]
password = mysql_user_pass['mysql_pass'][0]

# %% [markdown]
# <div class="alert alert-block alert-warning">
#         Create an engine to connect to the mysql database
# </div>

# %%
from sqlalchemy import create_engine

engine = create_engine(f'mysql+pymysql://{username}:{password}@localhost:3306/developer_survey_2020')

# %% [markdown]
# <a id='3.0'></a>
# <div class="alert alert-block alert-danger">
# <h2>Load Data</h2>
# </div>

# %%
'''
StackOverflow Annual Developer Survey 2020

With nearly 65,000 responses fielded from over 180 countries and dependent territories, our 2020 Annual 
Developer Survey examines all aspects of the developer experience from career satisfaction and job search 
to education and opinions on open-source software.
'''

df = pd.read_csv('../../../all_dfs/developer_survey_2020/survey_results_public.csv', index_col='Respondent')
df.head(3)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
# 3              I code primarily as a hobby      Yes  NaN         15      NaN
#
#             CompTotal  ConvertedComp             Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN             Germany   European Euro
# 2                 NaN            NaN      United Kingdom  Pound sterling
# 3                 NaN            NaN  Russian Federation             NaN
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
# 3                     NaN                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
# 3                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
#
#                                Ethnicity Gender  \
# Respondent
# 1           White or of European descent    Man
# 2                                    NaN    NaN
# 3                                    NaN    NaN
#
#                                                    JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies ...
# 2                                                         NaN
# 3                                                         NaN
#
#                         JobSat                                       JobSeek  \
# Respondent
# 1           Slightly satisfied  I am not interested in new job opportunities
# 2            Very dissatisfied  I am not interested in new job opportunities
# 3                          NaN                                           NaN
#
#               LanguageDesireNextYear        LanguageWorkedWith  \
# Respondent
# 1             C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 2                       Python;Swift          JavaScript;Swift
# 3           Objective-C;Python;Swift  Objective-C;Python;Swift
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1           Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                    Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                    NaN       NaN
#
#                  NEWDevOpsImpt         NEWEdImpt NEWJobHunt  \
# Respondent
# 1           Somewhat important  Fairly important        NaN
# 2                          NaN  Fairly important        NaN
# 3                          NaN               NaN        NaN
#
#            NEWJobHuntResearch       NEWLearn NEWOffTopic NEWOnboardGood  \
# Respondent
# 1                         NaN    Once a year    Not sure            NaN
# 2                         NaN    Once a year    Not sure            NaN
# 3                         NaN  Once a decade         NaN            NaN
#
#            NEWOtherComms                       NEWOvertime  \
# Respondent
# 1                     No  Often: 1-2 days per week or more
# 2                     No                               NaN
# 3                     No                               NaN
#
#                                           NEWPurchaseResearch NEWPurpleLink  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...        Amused
# 2                                                         NaN        Amused
# 3                                                         NaN           NaN
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
#
#                              OrgSize  \
# Respondent
# 1                   2 to 9 employees
# 2           1,000 to 4,999 employees
# 3                                NaN
#
#                                     PlatformDesireNextYear PlatformWorkedWith  \
# Respondent
# 1           Android;iOS;Kubernetes;Microsoft Azure;Windows            Windows
# 2                               iOS;Kubernetes;Linux;MacOS                iOS
# 3                                                      NaN                NaN
#
#                              PurchaseWhat                Sexuality SOAccount  \
# Respondent
# 1                                     NaN  Straight / Heterosexual        No
# 2           I have little or no influence                      NaN       Yes
# 3                                     NaN                      NaN       Yes
#
#                      SOComm                           SOPartFreq  \
# Respondent
# 1            No, not at all                                  NaN
# 2           Yes, definitely  Less than once per month or monthly
# 3             Yes, somewhat      A few times per month or weekly
#
#                        SOVisitFreq                  SurveyEase  \
# Respondent
# 1           Multiple times per day  Neither easy nor difficult
# 2           Multiple times per day                         NaN
# 3            Daily or almost daily  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
#
#            WebframeDesireNextYear    WebframeWorkedWith  \
# Respondent
# 1                    ASP.NET Core  ASP.NET;ASP.NET Core
# 2                             NaN                   NaN
# 3                             NaN                   NaN
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
#
#            YearsCodePro
# Respondent
# 1                    27
# 2                     4
# 3                   NaN

# %%
df_schema = pd.read_csv('../../../all_dfs/developer_survey_2020/survey_results_schema.csv')
df_schema
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %% [markdown]
# <a id='4.0'></a>
# <div class="alert alert-block alert-danger">
# <h2>Dataframes to SQL</h2>
# </div>

# %%
def uniquestosql(df, col):
    # create a dataframe with unique values to send to sql
    df_unique = pd.DataFrame(data=df[col].unique(), columns=[col]).dropna()
    
    # send the dataframe to sql
    # if_exists{‘fail’, ‘replace’, ‘append’}, default ‘fail’
    df_unique.to_sql(col, con=engine, if_exists='replace')
    
    # replace the values in the main dataframe with the index of the df_unique
    for unq in df_unique[col]:
        ind = df_unique[(df_unique[col] == unq)].index
        df[col] = df[col].replace(unq, str(ind[0]))
        
    return df

# %%
cols = ['MainBranch', 'Hobbyist', 'CompFreq', 'Country', 'CurrencyDesc', 'CurrencySymbol', 'EdLevel',
        'Employment', 'Gender', 'JobSat', 'JobSeek', 'NEWDevOps', 'NEWDevOpsImpt', 'NEWEdImpt', 'NEWLearn',
       'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms', 'NEWOvertime', 'NEWPurpleLink', 'OpSys', 'OrgSize',
       'PurchaseWhat', 'Sexuality', 'SOAccount', 'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase',
       'SurveyLength', 'Trans', 'UndergradMajor', 'WelcomeChange']

for col in cols:
    df = uniquestosql(df, col)

# %% [markdown]
# <a id='5.0'></a>
# <div class="alert alert-block alert-danger">
# <h2>Send the main dataframe replaced with index values</h2>
# </div>

# %%
pd.set_option('display.max_columns',100)

df.head(3)
# Out:
#            MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# Respondent
# 1                   0        0  NaN         13        0        NaN
# 2                   0        1  NaN         19      NaN        NaN
# 3                   1        0  NaN         15      NaN        NaN
#
#             ConvertedComp Country CurrencyDesc CurrencySymbol  \
# Respondent
# 1                     NaN       0            0              0
# 2                     NaN       1            1              1
# 3                     NaN       2          NaN            NaN
#
#            DatabaseDesireNextYear                         DatabaseWorkedWith  \
# Respondent
# 1            Microsoft SQL Server  Elasticsearch;Microsoft SQL Server;Oracle
# 2                             NaN                                        NaN
# 3                             NaN                                        NaN
#
#                                                       DevType EdLevel  \
# Respondent
# 1           Developer, desktop or enterprise applications;...       0
# 2                     Developer, full-stack;Developer, mobile       1
# 3                                                         NaN     NaN
#
#            Employment                     Ethnicity Gender  \
# Respondent
# 1                   0  White or of European descent      0
# 2                   1                           NaN    NaN
# 3                 NaN                           NaN    NaN
#
#                                                    JobFactors JobSat JobSeek  \
# Respondent
# 1           Languages, frameworks, and other technologies ...      0       0
# 2                                                         NaN      1       0
# 3                                                         NaN    NaN     NaN
#
#               LanguageDesireNextYear        LanguageWorkedWith  \
# Respondent
# 1             C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 2                       Python;Swift          JavaScript;Swift
# 3           Objective-C;Python;Swift  Objective-C;Python;Swift
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1           Confluence;Jira;Slack;Microsoft Azure;Trello         0
# 2                    Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                    NaN       NaN
#
#            NEWDevOpsImpt NEWEdImpt NEWJobHunt NEWJobHuntResearch NEWLearn  \
# Respondent
# 1                      0         0        NaN                NaN        0
# 2                    NaN         0        NaN                NaN        0
# 3                    NaN       NaN        NaN                NaN        1
#
#            NEWOffTopic NEWOnboardGood NEWOtherComms NEWOvertime  \
# Respondent
# 1                    0            NaN             0           0
# 2                    0            NaN             0         NaN
# 3                  NaN            NaN             0         NaN
#
#                                           NEWPurchaseResearch NEWPurpleLink  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...             0
# 2                                                         NaN             0
# 3                                                         NaN           NaN
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
#
#                                                      NEWStuck OpSys OrgSize  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...     0       0
# 2           Visit Stack Overflow;Go for a walk or other ph...     1       1
# 3                                                         NaN     2     NaN
#
#                                     PlatformDesireNextYear PlatformWorkedWith  \
# Respondent
# 1           Android;iOS;Kubernetes;Microsoft Azure;Windows            Windows
# 2                               iOS;Kubernetes;Linux;MacOS                iOS
# 3                                                      NaN                NaN
#
#            PurchaseWhat Sexuality SOAccount SOComm SOPartFreq SOVisitFreq  \
# Respondent
# 1                   NaN         0         0      0        NaN           0
# 2                     1       NaN         1      1          1           0
# 3                   NaN       NaN         1      2          2           1
#
#            SurveyEase SurveyLength Trans UndergradMajor  \
# Respondent
# 1                   0            0     0              0
# 2                 NaN          NaN   NaN              0
# 3                   0            0   NaN            NaN
#
#            WebframeDesireNextYear    WebframeWorkedWith WelcomeChange  \
# Respondent
# 1                    ASP.NET Core  ASP.NET;ASP.NET Core             0
# 2                             NaN                   NaN             1
# 3                             NaN                   NaN             1
#
#             WorkWeekHrs YearsCode YearsCodePro
# Respondent
# 1                  50.0        36           27
# 2                   NaN         7            4
# 3                   NaN         4          NaN

# %%
df.to_sql('main_table', con=engine, if_exists='replace')

# %% [markdown]
# <a id='6.0'></a>
# <div class="alert alert-block alert-danger">
# <h2>Add comments into sql tables</h2>
# </div>

# %%
# get the table names in the sql
sql = 'SHOW TABLES FROM developer_survey_2020'
df_tables = pd.read_sql_query(sql, engine)
print(df_tables.iloc[:,0].values)
# Out:
# ['CompFreq' 'Country' 'CurrencyDesc' 'CurrencySymbol' 'EdLevel'
#  'Employment' 'Gender' 'Hobbyist' 'JobSat' 'JobSeek' 'main_table'
#  'MainBranch' 'NEWDevOps' 'NEWDevOpsImpt' 'NEWEdImpt' 'NEWLearn'
#  'NEWOffTopic' 'NEWOnboardGood' 'NEWOtherComms' 'NEWOvertime'
#  'NEWPurpleLink' 'OpSys' 'OrgSize' 'PurchaseWhat' 'Sexuality' 'SOAccount'
#  'SOComm' 'SOPartFreq' 'SOVisitFreq' 'SurveyEase' 'SurveyLength' 'Trans'
#  'UndergradMajor' 'WelcomeChange']

# %%
df_schema_list = list(df_schema["Column"].values)

# get the index number and the description in the QuestionText column by using the table names
for table in df_tables['Tables_in_developer_survey_2020']:
    if table in df_schema_list:
        ind = df_schema[df_schema['Column'] == table].index[0]
        txt = df_schema.loc[ind,'QuestionText']
        txt = txt.replace('"', "'")     # to solve error while "conn.execute(sql)"

        # update the sql tables according to each column description in df_schema
        sql = """
        ALTER TABLE developer_survey_2020.{}
        COMMENT = "{}";
        """.format(table, txt)

        with engine.begin() as conn:
            conn.execute(sql)

# %% [markdown]
# <a id='7.0'></a>
# <div class="alert alert-block alert-danger">
# <h2>Add comments into columns in a sql table</h2>
# </div>

# %%
# get the column names of the main table in the sql
sql = 'SHOW COLUMNS FROM developer_survey_2020.main_table;'
df_col = pd.read_sql_query(sql, engine)['Field']

for col in df_col:
    # the first column is index.
    if col != 'Respondent':
#         print(col)
        # get the index number and the description in the QuestionText column by using the table column names
        ind = df_schema[df_schema['Column'] ==col].index[0]
        txt = df_schema.loc[ind,'QuestionText']
        txt = txt.replace('"', "'")     # to solve error while "conn.execute(sql)"
        
        sql = """
        ALTER TABLE developer_survey_2020.main_table
        CHANGE COLUMN {} {} TEXT NULL DEFAULT NULL COMMENT "{}";
        """.format(col, col, txt)
            
        try:
            # update the columns according to each column description in df_schema
            sql = """
            ALTER TABLE developer_survey_2020.main_table
            CHANGE COLUMN {} {} TEXT NULL DEFAULT NULL COMMENT '{}';
            """.format(col, col, txt)
            with engine.begin() as conn:
                conn.execute(sql)
        except:
            sql = """
            ALTER TABLE developer_survey_2020.main_table
            CHANGE COLUMN {} {} TEXT NULL DEFAULT NULL COMMENT "{}";
            """.format(col, col, txt)
            with engine.begin() as conn:
                conn.execute(sql)
